# %% [markdown]
# # KNN Regression and Evaluation

# %%
library('caret')
# Out:
# Loading required package: ggplot2
#
# Loading required package: lattice

# %% [markdown]
# # simulation

# %%
x = runif(1000,-1,1)
y = x^2 # f(x) = x^2
e = rnorm(1000,0,1/10)
y = y + e
plot(x,y)
# Out:
# plot without title

# %%
df = data.frame(x=x,y=y)

# %%
flds = createFolds(1:nrow(df),k=2)
flds
# Out:
# $Fold1
#   [1]   1   4   5   7  11  13  14  15  20  21  22  25  26  27  29  34  35  36
#  [19]  37  40  41  42  43  44  46  47  48  50  53  55  56  62  66  68  69  71
#  [37]  72  73  74  75  77  79  84  86  88  89  90  98  99 100 102 104 105 109
#  [55] 112 113 116 117 119 120 121 122 124 127 129 131 132 134 136 140 142 143
#  [73] 144 145 147 149 151 152 157 158 159 162 163 164 167 168 169 171 173 174
#  [91] 177 179 180 182 183 184 185 188 190 194 197 201 202 204 206 208 210 211
# [109] 217 223 224 225 227 228 229 234 235 236 240 242 243 244 246 247 250 253
# [127] 255 256 257 259 261 263 264 266 271 273 274 276 279 280 283 284 285 286
# [145] 287 289 291 293 296 297 300 302 306 311 312 315 317 318 320 321 322 330
# [163] 331 333 334 336 338 340 341 342 343 345 346 347 349 352 356 359 361 363
# [181] 365 368 369 370 371 372 373 375 379 380 382 383 387 389 390 391 398 402
# [199] 404 406 409 412 413 414 415 420 421 423 427 429 432 434 437 440 443 444
# [217] 445 450 451 452 453 454 458 460 461 462 463 464 466 467 469 470 472 473
# [235] 474 475 477 479 480 483 484 486 487 489 490 491 494 497 499 500 501 503
# [253] 504 505 507 508 509 510 513 514 517 518 520 521 526 529 532 533 534 535
# [271] 536 537 542 543 545 546 547 548 551 554 555 558 560 561 562 563 565 567
# [289] 568 571 574 576 577 579 580 581 582 585 586 589 590 592 593 597 600 601
# [307] 602 603 605 606 609 610 613 617 618 624 625 626 628 630 631 632 634 635
# [325] 636 639 640 643 644 646 648 652 653 658 659 663 665 666 671 672 674 675
# [343] 678 679 682 686 688 691 692 693 694 695 696 697 699 702 705 707 710 712
# [361] 714 715 719 720 721 722 723 727 732 736 739 741 744 745 746 754 755 756
# [379] 757 758 760 761 766 768 771 773 775 776 779 781 783 784 785 787 788 789
# [397] 792 797 798 802 804 805 811 812 814 816 817 820 821 823 825 826 827 834
# [415] 838 841 842 843 844 847 849 852 853 857 858 860 861 862 863 864 865 866
# [433] 868 870 873 874 877 878 883 884 891 893 894 897 899 908 910 911 916 918
# [451] 922 923 924 925 926 927 929 932 933 934 937 938 939 940 941 942 945 946
# [469] 948 949 950 951 952 955 956 958 961 963 965 966 967 968 970 972 975 978
# [487] 979 980 981 982 983 984 988 990 991 993 994 996 997 999
#
# $Fold2
#   [1]    2    3    6    8    9   10   12   16   17   18   19   23   24   28   30
#  [16]   31   32   33   38   39   45   49   51   52   54   57   58   59   60   61
#  [31]   63   64   65   67   70   76   78   80   81   82   83   85   87   91   92
#  [46]   93   94   95   96   97  101  103  106  107  108  110  111  114  115  118
#  [61]  123  125  126  128  130  133  135  137  138  139  141  146  148  150  153
#  [76]  154  155  156  160  161  165  166  170  172  175  176  178  181  186  187
#  [91]  189  191  192  193  195  196  198  199  200  203  205  207  209  212  213
# [106]  214  215  216  218  219  220  221  222  226  230  231  232  233  237  238
# [121]  239  241  245  248  249  251  252  254  258  260  262  265  267  268  269
# [136]  270  272  275  277  278  281  282  288  290  292  294  295  298  299  301
# [151]  303  304  305  307  308  309  310  313  314  316  319  323  324  325  326
# [166]  327  328  329  332  335  337  339  344  348  350  351  353  354  355  357
# [181]  358  360  362  364  366  367  374  376  377  378  381  384  385  386  388
# [196]  392  393  394  395  396  397  399  400  401  403  405  407  408  410  411
# [211]  416  417  418  419  422  424  425  426  428  430  431  433  435  436  438
# [226]  439  441  442  446  447  448  449  455  456  457  459  465  468  471  476
# [241]  478  481  482  485  488  492  493  495  496  498  502  506  511  512  515
# [256]  516  519  522  523  524  525  527  528  530  531  538  539  540  541  544
# [271]  549  550  552  553  556  557  559  564  566  569  570  572  573  575  578
# [286]  583  584  587  588  591  594  595  596  598  599  604  607  608  611  612
# [301]  614  615  616  619  620  621  622  623  627  629  633  637  638  641  642
# [316]  645  647  649  650  651  654  655  656  657  660  661  662  664  667  668
# [331]  669  670  673  676  677  680  681  683  684  685  687  689  690  698  700
# [346]  701  703  704  706  708  709  711  713  716  717  718  724  725  726  728
# [361]  729  730  731  733  734  735  737  738  740  742  743  747  748  749  750
# [376]  751  752  753  759  762  763  764  765  767  769  770  772  774  777  778
# [391]  780  782  786  790  791  793  794  795  796  799  800  801  803  806  807
# [406]  808  809  810  813  815  818  819  822  824  828  829  830  831  832  833
# [421]  835  836  837  839  840  845  846  848  850  851  854  855  856  859  867
# [436]  869  871  872  875  876  879  880  881  882  885  886  887  888  889  890
# [451]  892  895  896  898  900  901  902  903  904  905  906  907  909  912  913
# [466]  914  915  917  919  920  921  928  930  931  935  936  943  944  947  953
# [481]  954  957  959  960  962  964  969  971  973  974  976  977  985  986  987
# [496]  989  992  995  998 1000

# %% [markdown]
# # test/train split

# %%
test_df = df[flds[[1]],]
train_df = df[flds[[2]],]

# %%
dim(test_df)
dim(train_df)
# Out:
# [1] 500   2
# [1] 500   2

# %%
# build on the testing data
knn_mod = knnreg(y~.,data=train_df,k=5)

# %%
train_preds = predict(knn_mod,train_df)

# %%
RMSE_train = sqrt(mean((train_df$y-train_preds)^2))

# %%
RMSE_train
# Out:
# [1] 0.09128565

# %%
test_preds = predict(knn_mod,test_df)

# %%
RMSE_test = sqrt(mean((test_df$y-test_preds)^2))

# %%
RMSE_test
# Out:
# [1] 0.1096604

# %%
plot(x,y)
xe = data.frame(x=sort(runif(1000,-1,1)))
lines(xe$x,predict(knn_mod,xe),col='red')
lines(xe$x,xe$x^2,col='blue')
# Out:
# plot without title

# %% [markdown]
# notice how the training RMSE is typically loweer than the testing RMSE

# %% [markdown]
# # k fold cross validation

# %%
flds = createFolds(1:nrow(df),k=5)
flds
# Out:
# $Fold1
#   [1]   2   5  12  13  17  34  36  48  49  50  54  60  63  66  78  87  88  91
#  [19]  93  96 109 112 113 117 119 123 124 140 146 148 149 153 157 159 163 171
#  [37] 188 190 200 202 204 207 212 215 219 231 235 236 245 246 253 255 256 257
#  [55] 260 266 270 274 287 296 301 302 306 314 328 340 348 350 352 353 357 358
#  [73] 361 362 373 374 384 387 394 403 408 415 422 424 427 428 434 437 448 456
# [163] 795 799 805 806 807 810 820 832 834 840 844 850 856 863 866 873 874 877
# [181] 884 886 895 915 916 920 921 927 935 938 940 953 955 956 965 977 984 985
# [199] 989 993
#
# $Fold5
#   [1]   1   4   7  11  14  18  22  24  28  29  30  32  39  43  44  46  55  57
#  [19]  61  65  71  76  77  92  94  95  98 114 118 125 127 138 143 145 150 173
#  [37] 175 177 182 185 186 187 189 192 209 227 238 239 247 250 254 259 262 263
#  [55] 264 265 272 273 276 278 279 284 286 294 299 300 311 312 318 326 330 334
#  [73] 337 341 343 360 370 375 377 389 391 399 413 421 423 426 433 438 443 447
#  [91] 453 454 457 458 461 466 467 491 494 496 504 508 509 524 529 531 539 542
# [109] 550 559 563 565 573 574 575 584 593 595 596 609 626 630 638 639 640 649
# [127] 650 652 654 658 663 664 671 673 676 680 684 700 703 706 710 714 721 722
# [145] 728 729 732 734 747 750 751 760 764 766 775 780 782 787 789 791 792 798
# [163] 809 815 817 818 825 831 836 838 839 847 851 858 861 862 868 871 880 889
# [181] 897 901 902 905 911 912 923 924 929 934 939 943 949 958 975 983 988 995
# [199] 996 997

# %%
lengths(flds)
# Out:
# Fold1 Fold2 Fold3 Fold4 Fold5
#   200   200   200   200   200

# %%
i = 1
test_df = df[flds[[i]],]
train_df = df[unlist(flds[-i]),]

# %%
dim(test_df)
dim(train_df)
# Out:
# [1] 200   2
# [1] 800   2

# %%
knn_mod = knnreg(y~.,data=train_df,k=10)

train_preds = predict(knn_mod,train_df)
RMSE_train = sqrt(mean((train_df$y-train_preds)^2))

test_preds = predict(knn_mod,test_df)
RMSE_test = sqrt(mean((test_df$y-test_preds)^2))

RMSE_train
RMSE_test
# Out:
# [1] 0.09271757
# [1] 0.1159428

# %% [markdown]
# let's put this in a function

# %%
tt_split_eval = function(train_idx,test_idx){
    test_df = df[test_idx,]
    train_df = df[train_idx,]
    
    knn_mod = knnreg(y~.,data=train_df,k=5)

    train_preds = predict(knn_mod,train_df)
    RMSE_train = sqrt(mean((train_df$y-train_preds)^2))

    test_preds = predict(knn_mod,test_df)
    RMSE_test = sqrt(mean((test_df$y-test_preds)^2))

    return(data.frame(train=RMSE_train,
        test=RMSE_test
                ))
}

# %%
flds = createFolds(1:nrow(df),k=10)
rmses = lapply(1:length(flds),function(i){
    tdf = tt_split_eval(train_idx = unlist(flds[-i]),test_idx = flds[[i]])
    tdf$i = i 
    return(tdf)
})

# %%
rmses[[1]]
# Out:
#   train      test      i
# 1 0.09063457 0.1075498 1

# %%
rmses[[2]]
# Out:
#   train      test      i
# 1 0.09007994 0.1088015 2

# %%
RMSE = Reduce('rbind',rmses)

# %%
RMSE
# Out:
#    train      test      i
# 1  0.09063457 0.1075498  1
# 2  0.09007994 0.1088015  2
# 3  0.09089818 0.1025149  3
# 4  0.08942264 0.1170190  4
# 5  0.08943102 0.1126519  5
# 6  0.08811783 0.1218575  6
# 7  0.08981664 0.1181531  7
# 8  0.09038827 0.1071892  8
# 9  0.08948017 0.1120682  9
# 10 0.09074159 0.1006625 10

# %%
library('reshape2')

# %%
mRMSE = reshape2::melt(RMSE,id.vars='i')
mRMSE
# Out:
#    i  variable value
# 1   1 train    0.09063457
# 2   2 train    0.09007994
# 3   3 train    0.09089818
# 4   4 train    0.08942264
# 5   5 train    0.08943102
# 6   6 train    0.08811783
# 7   7 train    0.08981664
# 8   8 train    0.09038827
# 9   9 train    0.08948017
# 10 10 train    0.09074159
# 11  1 test     0.10754981
# 12  2 test     0.10880145
# 13  3 test     0.10251489
# 14  4 test     0.11701901
# 15  5 test     0.11265186
# 16  6 test     0.12185747
# 17  7 test     0.11815307
# 18  8 test     0.10718924
# 19  9 test     0.11206818
# 20 10 test     0.10066249

# %%
library('ggplot2')

# %%
ggplot(data=mRMSE,mapping=aes(x=i,y=value,color=variable))+
    geom_point()
# Out:
# plot without title

# %% [markdown]
# in total summary we can summarize the RMSEs

# %%
median(RMSE$train)
# Out:
# [1] 0.08994829

# %%
median(RMSE$test)
# Out:
# [1] 0.1104348

# %% [markdown]
# How can we use this to choose a value of $k$ for KNN? Use a train/validate/test 3-way split

# %%
flds = createFolds(1:nrow(df),k=10)
flds
# Out:
# $Fold01
#   [1]   3  15  22  56  57  64  65  94  97 109 114 115 121 134 136 143 149 160
#  [19] 177 179 181 188 214 215 248 276 288 322 329 330 331 349 352 359 372 379
#  [37] 391 402 412 413 418 430 474 475 483 485 488 490 495 496 520 524 526 534
#  [55] 546 549 554 562 576 577 584 598 600 625 633 650 654 666 671 672 673 684
#  [73] 723 727 740 751 752 763 764 768 783 801 808 813 830 831 832 846 848 851
#  [91] 867 897 914 919 920 929 956 962 963 987
#
# $Fold02
#   [1]   5   6   8  27  38  48  68  77  95 104 111 142 159 162 182 186 189 209
#  [19] 219 221 227 242 245 246 247 261 264 266 270 282 283 290 292 297 299 303
#  [37] 307 312 338 347 369 378 388 392 393 409 424 441 453 461 501 509 512 515
#  [55] 518 533 538 540 558 561 613 615 639 647 656 665 677 686 692 705 706 707
#  [73] 712 716 741 758 765 776 784 785 790 815 817 829 836 839 844 870 880 889
#  [91] 890 913 935 943 952 971 980 986 989 993
#
# $Fold03
#   [1]  23  39  46  54  59  70  73  78  81  89 105 113 118 127 135 137 150 155
#  [19] 167 180 196 237 238 243 250 284 289 294 305 309 313 342 350 362 395 400
#  [37] 404 414 421 433 439 443 444 447 455 456 465 487 497 499 502 523 536 542
#  [55] 552 556 572 579 589 603 605 609 612 619 628 636 645 649 652 653 675 694
#  [73] 698 719 742 759 767 793 810 824 828 834 837 842 849 873 878 884 888 892
#  [91] 894 895 907 961 968 973 976 983 990 996
#
# $Fold04
#   [1]   4  32  35  37  44  71  76  86  92 110 126 141 152 170 171 172 183 194
#  [19] 210 213 218 222 229 235 244 254 258 259 262 269 271 274 319 343 356 357
#  [37] 383 403 407 415 426 437 442 445 449 454 472 478 480 486 503 507 525 529
#  [55] 530 544 553 564 583 585 586 611 623 630 641 655 658 663 664 685 695 710
#  [73] 711 735 736 789 791 797 799 803 809 812 823 838 840 858 864 868 871 876
#  [91] 893 899 901 928 930 945 950 953 965 991
#
# $Fold05
#   [1]  12  28  30  36  40  61  88  98 103 106 116 125 130 131 147 157 164 174
#  [19] 175 202 223 231 232 236 240 291 295 296 300 314 327 334 335 339 346 353
#  [37] 354 361 368 374 381 386 398 401 411 425 427 448 476 482 506 510 513 543
#  [1]   2  10  18  28  67  73  74  79  94  96  97 106 114 115 148 159 176 177 189
# [20] 198 215 216 231 235 265 273 275 278 280 287 308 314 326 335 344 355 356 367
# [39] 381 390 393 409 418 424 439 456 459 462 469 476 489 493 510 520 536 579 583
# [58] 584 635 645 649 655 656 658 667 669 671 685 725 743 755 759 765 771 774 785
# [77] 788 799 802 804 809 816 839 850 864 875 876 884 888 891
#
# $Fold10
#  [1]   3   4   8  13  16  17  23  24  26  37  42  49  54  63  91  95 119 124 132
# [20] 149 191 197 199 229 242 245 266 277 284 289 315 316 318 328 332 337 340 350
# [39] 370 371 378 380 411 415 419 428 457 464 473 485 487 504 506 541 546 561 575
# [58] 578 592 599 602 605 616 626 643 650 668 670 674 682 693 716 717 718 726 727
# [77] 732 753 764 770 780 789 817 819 825 826 832 843 863 870 889 894

# %%
lengths(tv_flds)
# Out:
# Fold01 Fold02 Fold03 Fold04 Fold05 Fold06 Fold07 Fold08 Fold09 Fold10
#     90     90     90     89     89     91     89     90     90     92

# %%
j=1
val_idx = tv_flds[[j]]
train_idx = unlist(tv_flds[-j])

# %%
train_df = trainval_df[train_idx,]
val_df = trainval_df[val_idx,]

# %%
dim(train_df)
dim(val_df)
# Out:
# [1] 810   2
# [1] 90  2

# %%
tt_split_eval_k = function(train_idx,val_idx,k=1){
    train_df = trainval_df[train_idx,]
    val_df = trainval_df[val_idx,]
    
    knn_mod = knnreg(y~.,data=train_df,k=k)

    train_preds = predict(knn_mod,train_df)
    RMSE_train = sqrt(mean((train_df$y-train_preds)^2))

    val_preds = predict(knn_mod,val_df)
    RMSE_val = sqrt(mean((val_df$y-val_preds)^2))

    return(data.frame(train=RMSE_train,
        val=RMSE_val
                ))
}

# %%
tt_split_eval_k(train_idx,val_idx,k=5)
# Out:
#   train      val
# 1 0.08873465 0.1182842

# %%
tt_split_eval_k(train_idx,val_idx,k=10)
# Out:
#   train      val
# 1 0.09442581 0.1165916

# %%
RMSE = lapply(1:85,function(k){
    tdf = tt_split_eval_k(train_idx,val_idx,k=k)
    tdf$k = k
    return(tdf)
})
RMSE = Reduce('rbind',RMSE)
head(RMSE)
# Out:
#   train      val       k
# 1 0.00000000 0.1570135 1
# 2 0.06959364 0.1413379 2
# 3 0.08115376 0.1260517 3
# 4 0.08545024 0.1221917 4
# 5 0.08873465 0.1182842 5
# 6 0.09171879 0.1201452 6

# %%
mRMSE = melt(RMSE,id.vars='k')
head(mRMSE)
# Out:
#   k variable value
# 1 1 train    0.00000000
# 2 2 train    0.06959364
# 3 3 train    0.08115376
# 4 4 train    0.08545024
# 5 5 train    0.08873465
# 6 6 train    0.09171879

# %%
ggplot(data=mRMSE,mapping=aes(x=k,y=value,color=variable))+
    geom_point()+
    scale_x_sqrt()
# Out:
# plot without title

# %%
which.min(RMSE$val)
# Out:
# [1] 29

# %%
min_df = RMSE[which.min(RMSE$val),]
min_df
# Out:
#    train      val      k
# 29 0.09735597 0.109437 29

# %%
knn_mod = knnreg(y~.,data=trainval_df,k=min_df$k)

# %%
test_preds = predict(knn_mod,test_df)
RMSE_val = sqrt(mean((test_df$y-test_preds)^2))
RMSE_val
# Out:
# [1] 0.1059231

# %%
plot(x,y)
xe = data.frame(x=sort(runif(1000,-1,1)))
lines(xe$x,xe$x^2,col='blue',lwd=5)
lines(xe$x,predict(knn_mod,xe),col='red',lwd=5)
# Out:
# plot without title

# %% [markdown]
# can I do this in a cross validated way? yes use nested cross validation!

# %%
# outer loop = split into test and trainval datasets
# inner loop = MBP, split into train/val and search over k

# %%
flds = createFolds(1:nrow(df),k=10)

# %%
TEST_RMSE = rep(NA,length(flds))

for(i in 1:length(flds)){
    
    # split testing from trainval
    test_idx = flds[[i]]
    trainval_idx = unlist(flds[-i])
    test_df = df[test_idx,]
    trainval_df = df[trainval_idx,]
     
    #MODEL BUILDING PROCESS
    tv_flds = createFolds(1:nrow(trainval_df),k=10)
    
    K_seq = seq(1,75)
    VAL_MTX = array(NA,c(length(tv_flds),length(K_seq)))
    
    for(j in 1:length(tv_flds)){
        
        val_idx = tv_flds[[j]]
        train_idx = unlist(tv_flds[-j])
        train_df = trainval_df[train_idx,]
        val_df = trainval_df[val_idx,]

        for(k in K_seq){
            knn_mod = knnreg(y~.,data=train_df,k=k)
            val_preds = predict(knn_mod,val_df)
            VAL_MTX[j,k] = sqrt(mean((val_df$y-val_preds)^2))
        }
    }
    
    VAL_K = apply(VAL_MTX,2,mean)
    K_hat = K_seq[which.min(VAL_K)]
    
    knn_mod = knnreg(y~.,data=trainval_df,k=K_hat)
    
    # eval on testing data
    test_preds = predict(knn_mod,test_df)
    TEST_RMSE[i] = sqrt(mean((test_df$y-test_preds)^2))
}

# %% [markdown]
# consider for a single run:

# %%
ggplot(data=melt(VAL_MTX),mapping=aes(x=Var2,y=value,color=as.factor(Var1)))+geom_point()
# Out:
# plot without title

# %%
plot(VAL_K)
# Out:
# plot without title

# %%
K_hat = K_seq[which.min(VAL_K)]
K_hat
# Out:
# [1] 31

# %%
# overall

# %%
TEST_RMSE
# Out:
#  [1] 0.09615753 0.11658789 0.09614050 0.09849607 0.10270448 0.09637701
#  [7] 0.09819922 0.09966121 0.10340327 0.11231822

# %%
mean(TEST_RMSE)
# Out:
# [1] 0.1020045

# %%
sd(TEST_RMSE)

# %%
plot(VAL_K)
abline(h=mean(TEST_RMSE),col='red')
# Out:
# plot without title

# %% [markdown]
# How do we build the final model for prediction? Basically pull out the inner loop

# %%
tv_flds = createFolds(1:nrow(df),k=10) # use all df
    
K_seq = seq(1,75)
VAL_MTX = array(NA,c(length(tv_flds),length(K_seq)))

for(j in 1:length(tv_flds)){

    val_idx = tv_flds[[j]]
    train_idx = unlist(tv_flds[-j])
    train_df = df[train_idx,]
    val_df = df[val_idx,]

    for(k in K_seq){
        knn_mod = knnreg(y~.,data=train_df,k=k)
        val_preds = predict(knn_mod,val_df)
        VAL_MTX[j,k] = sqrt(mean((val_df$y-val_preds)^2))
    }
}

VAL_K = apply(VAL_MTX,2,mean)
K_hat = K_seq[which.min(VAL_K)]

# fit with all the data
knn_mod = knnreg(y~.,data=df,k=K_hat)

# %%
plot(VAL_K)
# Out:
# plot without title

# %%
K_hat
# Out:
# [1] 37

# %%
plot(x,y)
xe = data.frame(x=sort(runif(1000,-1,1)))
lines(xe$x,xe$x^2,col='blue',lwd=5)
lines(xe$x,predict(knn_mod,xe),col='red',lwd=5)
# Out:
# plot without title
